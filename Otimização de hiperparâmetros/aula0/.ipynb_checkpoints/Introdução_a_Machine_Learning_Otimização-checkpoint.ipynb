# %%
import pandas as pd
import numpy as np

uri = "https://gist.githubusercontent.com/guilhermesilveira/e99a526b2e7ccc6c3b70f53db43a87d2/raw/1605fc74aa778066bf2e6695e24d53cf65f2f447/machine-learning-carros-simulacao.csv"
dados = pd.read_csv(uri).drop(columns=["Unnamed: 0"], axis=1)
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano
# 0   30941.02        1               18  35085.22134
# 1   40557.96        1               20  12622.05362
# 2   89627.50        0               12  11440.79806
# 3   95276.14        0                3  43167.32682
# 4  117384.68        1                4  12770.11290

# %%
# situação horrível de "azar" onde as classes estão ordenadas por padrão

dados_azar = dados.sort_values("vendido", ascending=True)
x_azar = dados_azar[["preco", "idade_do_modelo","km_por_ano"]]
y_azar = dados_azar["vendido"]
dados_azar.head()
# Out:
#          preco  vendido  idade_do_modelo   km_por_ano
# 4999  74023.29        0               12  24812.80412
# 5322  84843.49        0               13  23095.63834
# 5319  83100.27        0               19  36240.72746
# 5316  87932.13        0               16  32249.56426
# 5315  77937.01        0               15  28414.50704

# %%
from sklearn.model_selection import cross_validate
from sklearn.dummy import DummyClassifier

SEED = 301
np.random.seed(SEED)

modelo = DummyClassifier()
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com dummy stratified, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com dummy stratified, 10 = [58.00, 58.00]

# %%
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier

SEED = 301
np.random.seed(SEED)

modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com cross validation, 10 = [73.83, 77.73]

# %%
# gerando dados elatorios de modelo de carro para simulacao de agrupamento ao usar nosso estimador

np.random.seed(SEED)
dados['modelo'] = dados.idade_do_modelo + np.random.randint(-2, 3, size=10000)
dados.modelo = dados.modelo + abs(dados.modelo.min()) + 1
dados.head()
# Out:
#        preco  vendido  idade_do_modelo   km_por_ano  modelo
# 0   30941.02        1               18  35085.22134      18
# 1   40557.96        1               20  12622.05362      24
# 2   89627.50        0               12  11440.79806      14
# 3   95276.14        0                3  43167.32682       6
# 4  117384.68        1                4  12770.11290       5

# %%
def imprime_resultados(results):
  media = results['test_score'].mean() * 100
  desvio = results['test_score'].std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

# %%
# GroupKFold para analisar como o modelo se comporta com novos grupos

from sklearn.model_selection import GroupKFold

SEED = 301
np.random.seed(SEED)

cv = GroupKFold(n_splits = 10)
modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 75.78
# Intervalo [73.67, 77.90]

# %%
# GroupKFold em um pipeline com StandardScaler e SVC

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline

SEED = 301
np.random.seed(SEED)

scaler = StandardScaler()
modelo = SVC()

pipeline = Pipeline([('transformacao',scaler), ('estimador',modelo)])

cv = GroupKFold(n_splits = 10)
results = cross_validate(pipeline, x_azar, y_azar, cv = cv, groups = dados.modelo, return_train_score=False)
imprime_resultados(results)
# Out:
# Accuracy médio 76.68
# Intervalo [74.28, 79.08]

# %%
from sklearn.model_selection import cross_validate
from sklearn.tree import DecisionTreeClassifier

SEED = 301
np.random.seed(SEED)

modelo = DecisionTreeClassifier(max_depth=2)
results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=False)
media = results['test_score'].mean()
desvio_padrao = results['test_score'].std()
print("Accuracy com cross validation, 10 = [%.2f, %.2f]" % ((media - 2 * desvio_padrao)*100, (media + 2 * desvio_padrao) * 100))
# Out:
# Accuracy com cross validation, 10 = [73.83, 77.73]

# %%
from sklearn.tree import export_graphviz
import graphviz

modelo.fit(x_azar, y_azar)
feature = x_azar.columns
dot_data = export_graphviz(modelo, out_file=None, filled=True, rounded=True, class_names=['não', 'sim'], feature_names=feature)
graph = graphviz.Source(dot_data)
graph

# %%
def roda_arvore_decisao(max_depth):
    SEED = 301
    np.random.seed(SEED)

    modelo = DecisionTreeClassifier(max_depth=max_depth)
    results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=True)
    print('max_depth: %d, treino = %.2f, teste = %.2f' % (max_depth, results['train_score'].mean()*100, results['test_score'].mean()*100))
    train_score = results['train_score'].mean()*100
    test_score = results['test_score'].mean()*100
    tabela = [max_depth, train_score, test_score]
    return tabela
    
resultados = [roda_arvore_decisao(i) for i in range(1, 33)]
resultados = pd.DataFrame(resultados, columns=['max_depth', 'train', 'test'])
# Out:
# max_depth: 1, treino = 75.79, teste = 75.78
# max_depth: 2, treino = 75.79, teste = 75.78
# max_depth: 3, treino = 78.75, teste = 78.70
# max_depth: 4, treino = 78.80, teste = 78.63
# max_depth: 5, treino = 78.97, teste = 78.56
# max_depth: 6, treino = 79.19, teste = 78.49
# max_depth: 7, treino = 79.44, teste = 78.04
# max_depth: 8, treino = 79.81, teste = 77.83
# max_depth: 9, treino = 80.36, teste = 77.55
# max_depth: 10, treino = 80.99, teste = 77.03
# max_depth: 11, treino = 81.79, teste = 76.30
# max_depth: 12, treino = 82.64, teste = 76.15
# max_depth: 13, treino = 83.56, teste = 75.71
# max_depth: 14, treino = 84.56, teste = 75.40
# max_depth: 15, treino = 85.62, teste = 75.32
# max_depth: 16, treino = 86.75, teste = 75.09
# max_depth: 17, treino = 87.80, teste = 74.92
# max_depth: 18, treino = 88.81, teste = 74.82
# max_depth: 19, treino = 89.85, teste = 74.04
# max_depth: 20, treino = 90.84, teste = 74.15
# max_depth: 21, treino = 91.80, teste = 73.81
# max_depth: 22, treino = 92.70, teste = 73.92
# max_depth: 23, treino = 93.48, teste = 73.78
# max_depth: 24, treino = 94.27, teste = 73.48
# max_depth: 25, treino = 95.04, teste = 73.18
# max_depth: 26, treino = 95.73, teste = 72.99
# max_depth: 27, treino = 96.25, teste = 73.19
# max_depth: 28, treino = 96.84, teste = 72.78
# max_depth: 29, treino = 97.28, teste = 72.85
# max_depth: 30, treino = 97.65, teste = 72.33
# max_depth: 31, treino = 98.03, teste = 72.58
# max_depth: 32, treino = 98.26, teste = 72.42

# %%
import seaborn as sns

sns.lineplot(x='max_depth', y='train', data=resultados)
# Out:
# <AxesSubplot: xlabel='max_depth', ylabel='train'>

# %%
import matplotlib.pyplot as plt


sns.lineplot(x='max_depth', y='train', data=resultados)
sns.lineplot(x='max_depth', y='test', data=resultados)
plt.legend(['Treino', 'Teste'])

# %%
resultados.sort_values('test', ascending=False).head()
# Out:
#    max_depth      train   test
# 2          3  78.754444  78.70
# 3          4  78.800000  78.63
# 4          5  78.965556  78.56
# 5          6  79.190000  78.49
# 6          7  79.443333  78.04

# %%
def roda_arvore_decisao(max_depth, min_samples_leaf):
    SEED = 301
    np.random.seed(SEED)

    modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf=min_samples_leaf)
    results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=True)
    print('max_depth: %d, min_samples_leaf: %d, treino = %.2f, teste = %.2f' % (max_depth, min_samples_leaf, results['train_score'].mean()*100, results['test_score'].mean()*100))
    train_score = results['train_score'].mean()*100
    test_score = results['test_score'].mean()*100
    tabela = [max_depth, min_samples_leaf, train_score, test_score]
    return tabela
    
def busca():
    resultados = []
    for max_depth in range(1,33):
        for min_samples_leaf in [32, 64, 128, 256]:
            tabela = roda_arvore_decisao(max_depth, min_samples_leaf)
            resultados.append(tabela)
    resultados = pd.DataFrame(resultados, columns=['max_depth', 'min_samples_leaf', 'train', 'test'])
    return resultados

resultados = busca()
resultados.head()
# Out:
# max_depth: 1, min_samples_leaf: 32, treino = 75.79, teste = 75.78
# max_depth: 1, min_samples_leaf: 64, treino = 75.79, teste = 75.78
# max_depth: 1, min_samples_leaf: 128, treino = 75.79, teste = 75.78
# max_depth: 1, min_samples_leaf: 256, treino = 75.79, teste = 75.78
# max_depth: 2, min_samples_leaf: 32, treino = 75.79, teste = 75.78
# max_depth: 2, min_samples_leaf: 64, treino = 75.79, teste = 75.78
# max_depth: 2, min_samples_leaf: 128, treino = 75.79, teste = 75.78
# max_depth: 2, min_samples_leaf: 256, treino = 75.79, teste = 75.78
# max_depth: 3, min_samples_leaf: 32, treino = 78.75, teste = 78.70
# max_depth: 3, min_samples_leaf: 64, treino = 78.75, teste = 78.70
# max_depth: 3, min_samples_leaf: 128, treino = 78.75, teste = 78.70
# max_depth: 3, min_samples_leaf: 256, treino = 78.75, teste = 78.70
# max_depth: 4, min_samples_leaf: 32, treino = 78.76, teste = 78.65
# max_depth: 4, min_samples_leaf: 64, treino = 78.76, teste = 78.61
# max_depth: 4, min_samples_leaf: 128, treino = 78.75, teste = 78.70
# max_depth: 4, min_samples_leaf: 256, treino = 78.75, teste = 78.70
# max_depth: 5, min_samples_leaf: 32, treino = 78.80, teste = 78.46
# max_depth: 5, min_samples_leaf: 64, treino = 78.78, teste = 78.41
# max_depth: 5, min_samples_leaf: 128, treino = 78.79, teste = 78.32
# max_depth: 5, min_samples_leaf: 256, treino = 78.75, teste = 78.62
# max_depth: 6, min_samples_leaf: 32, treino = 78.91, teste = 77.87
# max_depth: 6, min_samples_leaf: 64, treino = 78.91, teste = 78.06
# max_depth: 6, min_samples_leaf: 128, treino = 78.88, teste = 77.84
# max_depth: 6, min_samples_leaf: 256, treino = 78.82, teste = 78.27
# max_depth: 7, min_samples_leaf: 32, treino = 79.11, teste = 77.81
# max_depth: 7, min_samples_leaf: 64, treino = 79.03, teste = 77.95
# max_depth: 7, min_samples_leaf: 128, treino = 78.94, teste = 77.84
# max_depth: 7, min_samples_leaf: 256, treino = 78.87, teste = 78.20
# max_depth: 8, min_samples_leaf: 32, treino = 79.31, teste = 77.73
# max_depth: 8, min_samples_leaf: 64, treino = 79.29, teste = 77.91
# max_depth: 8, min_samples_leaf: 128, treino = 79.05, teste = 77.54
# max_depth: 8, min_samples_leaf: 256, treino = 78.91, teste = 78.18
# max_depth: 9, min_samples_leaf: 32, treino = 79.57, teste = 77.31
# max_depth: 9, min_samples_leaf: 64, treino = 79.45, teste = 77.44
# max_depth: 9, min_samples_leaf: 128, treino = 79.13, teste = 77.45
# max_depth: 9, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 10, min_samples_leaf: 32, treino = 79.84, teste = 77.55
# max_depth: 10, min_samples_leaf: 64, treino = 79.55, teste = 77.45
# max_depth: 10, min_samples_leaf: 128, treino = 79.17, teste = 77.44
# max_depth: 10, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 11, min_samples_leaf: 32, treino = 80.01, teste = 77.47
# max_depth: 11, min_samples_leaf: 64, treino = 79.65, teste = 77.29
# max_depth: 11, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 11, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 12, min_samples_leaf: 32, treino = 80.20, teste = 77.10
# max_depth: 12, min_samples_leaf: 64, treino = 79.68, teste = 77.25
# max_depth: 12, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 12, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 13, min_samples_leaf: 32, treino = 80.37, teste = 77.06
# max_depth: 13, min_samples_leaf: 64, treino = 79.74, teste = 77.28
# max_depth: 13, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 13, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 14, min_samples_leaf: 32, treino = 80.49, teste = 77.08
# max_depth: 14, min_samples_leaf: 64, treino = 79.78, teste = 77.28
# max_depth: 14, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 14, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 15, min_samples_leaf: 32, treino = 80.58, teste = 76.78
# max_depth: 15, min_samples_leaf: 64, treino = 79.81, teste = 77.27
# max_depth: 15, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 15, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 16, min_samples_leaf: 32, treino = 80.69, teste = 76.85
# max_depth: 16, min_samples_leaf: 64, treino = 79.84, teste = 77.21
# max_depth: 16, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 16, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 17, min_samples_leaf: 32, treino = 80.72, teste = 76.83
# max_depth: 17, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 17, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 17, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 18, min_samples_leaf: 32, treino = 80.74, teste = 76.84
# max_depth: 18, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 18, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 18, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 19, min_samples_leaf: 32, treino = 80.80, teste = 76.81
# max_depth: 19, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 19, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 19, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 20, min_samples_leaf: 32, treino = 80.81, teste = 76.83
# max_depth: 20, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 20, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 20, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 21, min_samples_leaf: 32, treino = 80.82, teste = 76.81
# max_depth: 21, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 21, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 21, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 22, min_samples_leaf: 32, treino = 80.83, teste = 76.82
# max_depth: 22, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 22, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 22, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 23, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 23, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 23, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 23, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 24, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 24, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 24, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 24, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 25, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 25, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 25, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 25, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 26, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 26, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 26, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 26, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 27, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 27, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 27, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 27, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 28, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 28, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 28, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 28, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 29, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 29, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 29, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 29, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 30, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 30, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 30, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 30, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 31, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 31, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 31, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 31, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 32, min_samples_leaf: 32, treino = 80.84, teste = 76.81
# max_depth: 32, min_samples_leaf: 64, treino = 79.85, teste = 77.18
# max_depth: 32, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 32, min_samples_leaf: 256, treino = 78.91, teste = 78.17
#    max_depth  min_samples_leaf      train   test
# 0          1                32  75.791111  75.78
# 1          1                64  75.791111  75.78
# 2          1               128  75.791111  75.78
# 3          1               256  75.791111  75.78
# 4          2                32  75.791111  75.78

# %%
resultados.sort_values('test', ascending=False).head()
# Out:
#     max_depth  min_samples_leaf      train  test
# 11          3               256  78.752222  78.7
# 10          3               128  78.752222  78.7
# 15          4               256  78.752222  78.7
# 14          4               128  78.752222  78.7
# 8           3                32  78.752222  78.7

# %%
corr = resultados.corr()

# %%
sns.heatmap(resultados.corr())
# Out:
# <AxesSubplot: >

# %%
pd.scatter_matrix(resultados)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pd.scatter_matrix(resultados)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'

# %%
sns.pairplot(resultados)

# %%
sns.set_theme(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot: >

# %%
def busca():
    resultados = []
    for max_depth in range(1,33):
        for min_samples_leaf in [128, 192, 256, 512]:
            tabela = roda_arvore_decisao(max_depth, min_samples_leaf)
            resultados.append(tabela)
    resultados = pd.DataFrame(resultados, columns=['max_depth', 'min_samples_leaf', 'train', 'test'])
    return resultados

resultados = busca()
resultados.head()
# Out:
# max_depth: 1, min_samples_leaf: 128, treino = 75.79, teste = 75.78
# max_depth: 1, min_samples_leaf: 192, treino = 75.79, teste = 75.78
# max_depth: 1, min_samples_leaf: 256, treino = 75.79, teste = 75.78
# max_depth: 1, min_samples_leaf: 512, treino = 75.79, teste = 75.78
# max_depth: 2, min_samples_leaf: 128, treino = 75.79, teste = 75.78
# max_depth: 2, min_samples_leaf: 192, treino = 75.79, teste = 75.78
# max_depth: 2, min_samples_leaf: 256, treino = 75.79, teste = 75.78
# max_depth: 2, min_samples_leaf: 512, treino = 75.79, teste = 75.78
# max_depth: 3, min_samples_leaf: 128, treino = 78.75, teste = 78.70
# max_depth: 3, min_samples_leaf: 192, treino = 78.75, teste = 78.70
# max_depth: 3, min_samples_leaf: 256, treino = 78.75, teste = 78.70
# max_depth: 3, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 4, min_samples_leaf: 128, treino = 78.75, teste = 78.70
# max_depth: 4, min_samples_leaf: 192, treino = 78.75, teste = 78.70
# max_depth: 4, min_samples_leaf: 256, treino = 78.75, teste = 78.70
# max_depth: 4, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 5, min_samples_leaf: 128, treino = 78.79, teste = 78.32
# max_depth: 5, min_samples_leaf: 192, treino = 78.77, teste = 78.44
# max_depth: 5, min_samples_leaf: 256, treino = 78.75, teste = 78.62
# max_depth: 5, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 6, min_samples_leaf: 128, treino = 78.88, teste = 77.84
# max_depth: 6, min_samples_leaf: 192, treino = 78.85, teste = 78.09
# max_depth: 6, min_samples_leaf: 256, treino = 78.82, teste = 78.27
# max_depth: 6, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 7, min_samples_leaf: 128, treino = 78.94, teste = 77.84
# max_depth: 7, min_samples_leaf: 192, treino = 78.86, teste = 78.04
# max_depth: 7, min_samples_leaf: 256, treino = 78.87, teste = 78.20
# max_depth: 7, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 8, min_samples_leaf: 128, treino = 79.05, teste = 77.54
# max_depth: 8, min_samples_leaf: 192, treino = 78.91, teste = 77.89
# max_depth: 8, min_samples_leaf: 256, treino = 78.91, teste = 78.18
# max_depth: 8, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 9, min_samples_leaf: 128, treino = 79.13, teste = 77.45
# max_depth: 9, min_samples_leaf: 192, treino = 78.94, teste = 77.95
# max_depth: 9, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 9, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 10, min_samples_leaf: 128, treino = 79.17, teste = 77.44
# max_depth: 10, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 10, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 10, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 11, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 11, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 11, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 11, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 12, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 12, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 12, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 12, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 13, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 13, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 13, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 13, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 14, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 14, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 14, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 14, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 15, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 15, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 15, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 15, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 16, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 16, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 16, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 16, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 17, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 17, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 17, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 17, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 18, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 18, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 18, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 18, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 19, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 19, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 19, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 19, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 20, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 20, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 20, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 20, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 21, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 21, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 21, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 21, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 22, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 22, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 22, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 22, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 23, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 23, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 23, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 23, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 24, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 24, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 24, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 24, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 25, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 25, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 25, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 25, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 26, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 26, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 26, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 26, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 27, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 27, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 27, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 27, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 28, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 28, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 28, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 28, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 29, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 29, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 29, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 29, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 30, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 30, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 30, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 30, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 31, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 31, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 31, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 31, min_samples_leaf: 512, treino = 77.53, teste = 77.47
# max_depth: 32, min_samples_leaf: 128, treino = 79.19, teste = 77.44
# max_depth: 32, min_samples_leaf: 192, treino = 78.98, teste = 77.97
# max_depth: 32, min_samples_leaf: 256, treino = 78.91, teste = 78.17
# max_depth: 32, min_samples_leaf: 512, treino = 77.53, teste = 77.47
#    max_depth  min_samples_leaf      train   test
# 0          1               128  75.791111  75.78
# 1          1               192  75.791111  75.78
# 2          1               256  75.791111  75.78
# 3          1               512  75.791111  75.78
# 4          2               128  75.791111  75.78

# %%
corr = resultados.corr()

# %%
sns.set_theme(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot: >

# %%
resultados.sort_values('test', ascending=False).head()
# Out:
#     max_depth  min_samples_leaf      train  test
# 13          4               192  78.752222  78.7
# 10          3               256  78.752222  78.7
# 14          4               256  78.752222  78.7
# 12          4               128  78.752222  78.7
# 8           3               128  78.752222  78.7

# %%
def roda_arvore_decisao(max_depth, min_samples_leaf, min_samples_split):
    SEED = 301
    np.random.seed(SEED)

    modelo = DecisionTreeClassifier(max_depth=max_depth, min_samples_leaf=min_samples_leaf)
    results = cross_validate(modelo, x_azar, y_azar, cv = 10, return_train_score=True)
    fit_time = results['fit_time'].mean()
    score_time = results['score_time'].mean()
    #print('max_depth: %d, min_samples_leaf: %d, min_samples_split = %d, treino = %.2f, teste = %.2f' % (max_depth, min_samples_leaf, min_samples_split, results['train_score'].mean()*100, results['test_score'].mean()*100))
    train_score = results['train_score'].mean()*100
    test_score = results['test_score'].mean()*100
    tabela = [max_depth, min_samples_leaf, min_samples_split, train_score, test_score, fit_time, score_time]
    return tabela

def busca():
    resultados = []
    for max_depth in range(1,33):
        for min_samples_leaf in [128, 192, 256, 512]:
            for min_samples_split in [32, 64, 128, 256]:
                tabela = roda_arvore_decisao(max_depth, min_samples_leaf, min_samples_split)
                resultados.append(tabela)
    resultados = pd.DataFrame(resultados, columns=['max_depth', 'min_samples_leaf', 'min_samples_split', 'train', 'test', 'fit_time', 'score_time'])
    return resultados

resultados = busca()
resultados.head()
# Out:
#    max_depth  min_samples_leaf  min_samples_split      train   test  fit_time  \
# 0          1               128                 32  75.791111  75.78  0.004970
# 1          1               128                 64  75.791111  75.78  0.004219
# 2          1               128                128  75.791111  75.78  0.004403
# 3          1               128                256  75.791111  75.78  0.004360
# 4          1               192                 32  75.791111  75.78  0.004562
#
#    score_time
# 0    0.001789
# 1    0.001199
# 2    0.001327
# 3    0.001658
# 4    0.001532

# %%
corr = resultados.corr()
sns.set_theme(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot: >

# %%
resultados.sort_values('test', ascending=False).head()
# Out:
#     max_depth  min_samples_leaf  min_samples_split      train  test  fit_time  \
# 40          3               256                 32  78.752222  78.7  0.007780
# 57          4               256                 64  78.752222  78.7  0.009109
# 54          4               192                128  78.752222  78.7  0.009975
# 53          4               192                 64  78.752222  78.7  0.011848
# 52          4               192                 32  78.752222  78.7  0.009468
#
#     score_time
# 40    0.001473
# 57    0.001825
# 54    0.001454
# 53    0.001348
# 52    0.001448

# %%
from sklearn.model_selection import GridSearchCV

# %%
SEED = 301
np.random.seed(SEED)

espaco_parametros = {
    'max_depth': [3, 5],
    'min_samples_split': [32, 64, 128],
    'min_samples_leaf': [32, 64, 128],
    'criterion': ['gini', 'entropy']
}

busca = GridSearchCV(DecisionTreeClassifier(), espaco_parametros, cv=GroupKFold(n_splits=10))
busca.fit(x_azar, y_azar, groups = dados.modelo)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.009143      0.001308         0.001642        0.000538
# 1       0.008542      0.000883         0.001295        0.000455
# 2       0.008244      0.000525         0.001772        0.000526
# 3       0.007946      0.000792         0.001524        0.000760
# 4       0.007805      0.000496         0.001457        0.000483
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               3                     32
# 1            gini               3                     32
# 2            gini               3                     32
# 3            gini               3                     64
# 4            gini               3                     64
#
#   param_min_samples_split                                             params  \
# 0                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 1                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 2                     128  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 3                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 4                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
#
#    split0_test_score  ...  split3_test_score  split4_test_score  \
# 0           0.804757  ...            0.78408           0.783181
# 1           0.804757  ...            0.78408           0.783181
# 2           0.804757  ...            0.78408           0.783181
# 3           0.804757  ...            0.78408           0.783181
# 4           0.804757  ...            0.78408           0.783181
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.797809           0.762866           0.781818            0.77551
# 1           0.797809           0.762866           0.781818            0.77551
# 2           0.797809           0.762866           0.781818            0.77551
# 3           0.797809           0.762866           0.781818            0.77551
# 4           0.797809           0.762866           0.781818            0.77551
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.790262         0.786726        0.011361                1
# 1           0.790262         0.786726        0.011361                1
# 2           0.790262         0.786726        0.011361                1
# 3           0.790262         0.786726        0.011361                1
# 4           0.790262         0.786726        0.011361                1
#
# [5 rows x 22 columns]

# %%
print(busca.best_params_)
print(busca.best_score_ *100)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 32, 'min_samples_split': 32}
# 78.67263337284332

# %%
melhor = busca.best_estimator_
melhor
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=32, min_samples_split=32)

# %%
from sklearn.metrics import accuracy_score


predicoes = melhor.predict(x_azar)
accuracy = accuracy_score(predicoes, y_azar) *100
print('Accuracy para os dados: %.2f%%' % accuracy)
# Out:
# Accuracy para os dados: 78.75%

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

SEED = 301
np.random.seed(SEED)

espaco_parametros = {
    'max_depth': [3, 5],
    'min_samples_split': [32, 64, 128],
    'min_samples_leaf': [32, 64, 128],
    'criterion': ['gini', 'entropy']
}

busca = GridSearchCV(DecisionTreeClassifier(), espaco_parametros, cv=KFold(n_splits=5, shuffle=True))
busca.fit(x_azar, y_azar)
resultados = pd.DataFrame(busca.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.009222      0.001187         0.002204        0.000681
# 1       0.007483      0.000287         0.001991        0.000640
# 2       0.007457      0.000367         0.001800        0.000401
# 3       0.007322      0.000594         0.001490        0.000525
# 4       0.006929      0.000373         0.001798        0.000400
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               3                     32
# 1            gini               3                     32
# 2            gini               3                     32
# 3            gini               3                     64
# 4            gini               3                     64
#
#   param_min_samples_split                                             params  \
# 0                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 1                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 2                     128  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 3                      32  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 4                      64  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0              0.784              0.776             0.8025              0.793
# 1              0.784              0.776             0.8025              0.793
# 2              0.784              0.776             0.8025              0.793
# 3              0.784              0.776             0.8025              0.793
# 4              0.784              0.776             0.8025              0.793
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.7795            0.787        0.009618                1
# 1             0.7795            0.787        0.009618                1
# 2             0.7795            0.787        0.009618                1
# 3             0.7795            0.787        0.009618                1
# 4             0.7795            0.787        0.009618                1

# %%
scores = cross_val_score(busca, x_azar, y_azar, cv = KFold(n_splits=5, shuffle=True))
scores
# Out:
# array([0.7895, 0.7825, 0.7905, 0.7715, 0.7995])

# %%
def imprime_score(scores):
  media = scores.mean() * 100
  desvio = scores.std() * 100
  print("Accuracy médio %.2f" % media)
  print("Intervalo [%.2f, %.2f]" % (media - 2 * desvio, media + 2 * desvio))

# %%
imprime_score(scores)
# Out:
# Accuracy médio 78.67
# Intervalo [76.80, 80.54]

# %%
melhor = busca.best_estimator_
print(melhor)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=32, min_samples_split=32)

# %%
feature = x_azar.columns
dot_data = export_graphviz(melhor, out_file=None, filled=True, rounded=True, class_names=['não', 'sim'], feature_names=feature)
graph = graphviz.Source(dot_data)
graph
